# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/insurance%20(2).csv")
df.shape
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
print(df.shape)
print(df.isnull().sum())
df.describe()
# Out:
# (1338, 7)
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

print("Encoding done!!")
df.head()
# Out:
# Encoding done!!
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = df [['age', 'sex', 'bmi','children','smoker','region']]
y = df['charges']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
model= LinearRegression()
model.fit(X_train,y_train)
print("Accuracy:", model.score(X_test , y_test))
# Out:
# Accuracy: 0.7377786263372946

# %%
# Predict charges for
# Age=35, female=0, BMI=28, children=1, smoker=1, region=2
prediction = model.predict([[35,0,28,1,1,2]])
print("predicted charges:", prediction)
# Out:
# predicted charges: [29936.86505439]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
    # same person but smoker=0
    prediction2 = model.predict([[35,0,28,1,0,2]])
    print("Non smoker charges:", prediction2)
# Out:
# Non smoker charges: [6140.5565456]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor(n_estimators=100)
model2.fit(X_train,y_train)
print("Random Forest Accuracy:",model2.score(X_test,y_test))
# Out:
# Random Forest Accuracy: 0.8343541762395565

# %%
import matplotlib.pyplot as plt
df['charges'].hist(bins=20, color='steelblue', edgecolor='white')
plt.title('insurance charges distribution')
plt.xlabel('charges')
plt.ylabel('count')
plt.show()

# %%
#smoker vs charges
import seaborn as sns
sns.boxplot(x='smoker',y='charges' , data=df)
plt.title('smoker  vs charges')
plt.show()

# %%
#Age vs charges
plt.scatter (df['age'],df['charges'], color='coral',alpha=0.5)
plt.title('Age vs charges')
plt.xlabel('age')
plt.ylabel('charges')
plt.show()

# %%
#CORRELATION  HEATMAP
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
